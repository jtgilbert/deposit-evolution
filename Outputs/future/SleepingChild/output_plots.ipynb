# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FormatStrFormatter
import numpy as np

# %%
df = pd.read_csv('SleepingChild_out.csv')

# %%
df
# Out:
#            Reach          DateTime      elev  width      D50     slope  \
# 0       upstream  2002-04-01 00:00  1579.594    0.0  63.6692 -0.008859
# 1       upstream  2002-04-01 01:00  1579.594    0.0  63.6692 -0.008858
# 2       upstream  2002-04-01 02:00  1579.594    0.0  63.6692 -0.008855
# 3       upstream  2002-04-01 03:00  1579.594    0.0  63.6692 -0.008855
# 4       upstream  2002-04-01 04:00  1579.594    0.0  63.6692 -0.008855
# ...          ...               ...       ...    ...      ...       ...
# 492715    feeder  2035-07-31 19:00     0.000    0.0   0.0000  0.000000
# 492716    feeder  2035-07-31 20:00     0.000    0.0   0.0000  0.000000
# 492717    feeder  2035-07-31 21:00     0.000    0.0   0.0000  0.000000
# 492718    feeder  2035-07-31 22:00     0.000    0.0   0.0000  0.000000
# 492719    feeder  2035-07-31 23:00     0.000    0.0   0.0000  0.000000
#
#            yield
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# ...          ...
# 492715  0.001249
# 492716  0.001249
# 492717  0.001249
# 492718  0.001249
# 492719  0.001249
#
# [492720 rows x 7 columns]

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])

# %%
upstream = df[df['Reach']=='upstream']
df_us = df[df['Reach']=='deposit_upstream']
df_ds = df[df['Reach']=='deposit_downstream']
downstream = df[df['Reach']=='downstream']

# %%
ts = np.arange(len(upstream))
#locator = mdates.YearLocator(1, month=4, day=1)

fig, ax = plt.subplots(2,2, figsize=(10,6))
ax[0,0].plot(upstream['DateTime'], upstream['elev'])
ax[0,0].set_title('Upstream')
ax[0,0].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax[0,0].set_xticklabels(ax[0,0].get_xticklabels(), rotation=45, ha='right')
ax[0,1].plot(df_us['DateTime'], df_us['elev'])
ax[0,1].set_title('Deposit Upstream')
ax[0,1].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax[0,1].set_xticklabels(ax[0,0].get_xticklabels(), rotation=45, ha='right')
ax[1,0].plot(df_ds['DateTime'], df_ds['elev'])
ax[1,0].set_title('Deposit Downstream')
ax[1,0].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax[1,0].set_xticklabels(ax[0,0].get_xticklabels(), rotation=45, ha='right')
ax[1,1].plot(downstream['DateTime'], downstream['elev'])
ax[1,1].set_title('Downstream')
ax[1,1].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax[1,1].set_xticklabels(ax[0,0].get_xticklabels(), rotation=45, ha='right')
#fig.supxlabel('Date', fontsize=14)
fig.supylabel('Bed Elevation (m)', fontsize=14)
plt.tight_layout()
#plt.savefig('/media/jordan/Elements/Geoscience/Bitterroot/figs/deposit_evolution/sc_elev.png', dpi=150)
plt.show()
# Out:
# /tmp/ipykernel_488787/1918216735.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0,0].set_xticklabels(ax[0,0].get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_488787/1918216735.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0,1].set_xticklabels(ax[0,0].get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_488787/1918216735.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1,0].set_xticklabels(ax[0,0].get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_488787/1918216735.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1,1].set_xticklabels(ax[0,0].get_xticklabels(), rotation=45, ha='right')

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].plot(upstream['slope'])
ax[0,0].set_title('Upstream')
ax[0,1].plot(df_us['slope'])
ax[0,1].set_title('Deposit upstream')
ax[1,0].plot(df_ds['slope'])
ax[1,0].set_title('Deposit downstream')
ax[1,1].plot(downstream['slope'])
ax[1,1].set_title('Downstream')
# Out:
# Text(0.5, 1.0, 'Downstream')

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].plot(upstream['width'])
ax[0,0].set_title('Upstream')
ax[0,1].plot(df_us['width'])
ax[0,1].set_title('Deposit upstream')
ax[1,0].plot(df_ds['width'])
ax[1,0].set_title('Deposit downstream')
ax[1,1].plot(downstream['width'])
ax[1,1].set_title('Downstream')
# Out:
# Text(0.5, 1.0, 'Downstream')

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].plot(upstream['D50'])
ax[0,0].set_title('Upstream')
ax[0,1].plot(df_us['D50'])
ax[0,1].set_title('Deposit upstream')
ax[1,0].plot(df_ds['D50'])

ax[1,0].set_title('Deposit downstream')
ax[1,1].plot(downstream['D50'])
ax[1,1].set_title('Downstream')
# Out:
# Text(0.5, 1.0, 'Downstream')

# %%
print(downstream['yield'].sum())
# Out:
# 3113066.6689861836

# %%
upstream['yield'].plot()
# Out:
# <Axes: >

# %%
downstream['yield'].plot()
# Out:
# <Axes: >

# %%
df_f = df[df['Reach'] == 'feeder']
df_f.reset_index(inplace=True)
downstream_r = downstream.reset_index()
#half_year_locator = mdates.MonthLocator(interval=6)
df_f['DateTime'] = pd.to_datetime(df_f['DateTime'])

fig, ax = plt.subplots(figsize=(10,5))
ax.plot(df_f['DateTime'], downstream_r['yield'], label='Exiting Reach')
ax.plot(df_f['DateTime'], df_f['yield'], label='Entering Reach')

#ax.set_yscale('log')
#ax.set_ylim((1e-2, 40000))
ax.set_ylabel('Sediment Yield (kg)', fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

ax.set_title('Sleeping Child Creek Debris Flow', fontsize=14)
plt.legend()
plt.savefig('/media/jordan/Elements/Geoscience/Bitterroot/figs/deposit_evolution/sc_inout.png', dpi=150)
plt.show()
# Out:
# /tmp/ipykernel_488787/4081732944.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f['DateTime'] = pd.to_datetime(df_f['DateTime'])
# /tmp/ipykernel_488787/4081732944.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
ratio = [12.41055644,
0.1255391767,
0.01812191104,
0.05051664753,
0.0325221365,
0.001433897333,
0.02657595337,
0.001391600967,
0.00006267496762,
0.000002457760317,
0.00001610370788,
0.0001104423215,
0.000002986237923,
0.0003212335368,
0.0004344048653,
0.000005989099838,
0.08860304814,
0.6971971205,
0.2949303529,
0.4744964498,
0.245912194,
8.062602965,
10.50516648,
0.5370996907,
3.147691425,
0.3871860862,
0.5313539789,
1.661764091,
0.7211855253,
1.237658521,
2.799657629,
0.7527574174]
year = [2002,
2003,
2004,
2005,
2006,
2007,
2008,
2009,
2010,
2011,
2012,
2013,
2014,
2015,
2016,
2017,
2018,
2019,
2020,
2021,
2022,
2023,
2024,
2025,
2026,
2027,
2028,
2029,
2030,
2031,
2032,
2033]

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(year, ratio, linewidth=3, color='darkblue')
ax.axhline(1, color='k', linestyle='dashed')
ax.set_ylabel(r'$\frac{Q_{s, out}}{Q_{s, in}}$', size=24)
ax.tick_params(axis='both', which='major', labelsize=16)
plt.title('Sleeping Child Creek Debris Flow', fontsize=24)
plt.xticks(np.arange(min(year), max(year)+1, 4))
#plt.savefig('/media/jordan/Elements/Geoscience/Bitterroot/figs/deposit_evolution/sc_qs_ratio.png', dpi=150)
plt.show()
